# %% [markdown]
# <a href="https://colab.research.google.com/github/Veera-Divya/LogicMojo-AI-ML-April26-Divya1280/blob/main/panda_practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
s= pd.Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s= pd.Series([1,2,3,4,'a'])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    a
# dtype: object

# %%
s= pd.Series([1,2,3,4])
s
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
s.values
# Out:
# array([1, 2, 3, 4])

# %%
s.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
print(s.name)
# Out:
# None

# %%
s.name = "calories"
print(s.name)
# Out:
# calories

# %%
s[0]
# Out:
# np.int64(1)

# %%
s[0:2]
# Out:
# 0    1
# 1    2
# Name: calories, dtype: int64

# %%
s[[2,3]]
# Out:
# 2    3
# 3    4
# Name: calories, dtype: int64

# %%
# iloc -> location based indexing for nummerical indexes
s.iloc[3]
# Out:
# np.int64(4)

# %%
s.iloc[[1,2,3]]
# Out:
# 1    2
# 2    3
# 3    4
# Name: calories, dtype: int64

# %%
index = ["apple", "mango", "papaya", "banana"]
s.index = index
s
# Out:
# apple     1
# mango     2
# papaya    3
# banana    4
# Name: calories, dtype: int64

# %%
s['apple']
# Out:
# np.int64(1)

# %%
# loc -> label based indexing
s.loc["apple"]
# Out:
# np.int64(1)

# %%
# in label based indexing your start and stop value both are inclided in the output
s.loc["apple": "banana"]
# Out:
# apple     1
# mango     2
# papaya    3
# banana    4
# Name: calories, dtype: int64

# %%
s.dtype
# Out:
# dtype('int64')

# %%
s.loc[["apple", "banana"]]
# Out:
# apple     1
# banana    4
# Name: calories, dtype: int64

# %%
fruit_protien = {
    "Avocado": 2.0,
    "Apple": 2.0,
    "grape": 3.0,
    "strwaberry": 4.0
}
s=pd.Series(fruit_protien, name="protien")
s
# Out:
# Avocado       2.0
# Apple         2.0
# grape         3.0
# strwaberry    4.0
# Name: protien, dtype: float64

# %%
#Conditional statements
s>1
# Out:
# Avocado       True
# Apple         True
# grape         True
# strwaberry    True
# Name: protien, dtype: bool

# %%
#conditional selection
s[s>1]
# Out:
# Avocado       2.0
# Apple         2.0
# grape         3.0
# strwaberry    4.0
# Name: protien, dtype: float64

# %%
s[(s>0.5) & (s<=2)]
# Out:
# Avocado    2.0
# Apple      2.0
# Name: protien, dtype: float64

# %%
# modifying the series
s["Mango"] = 2.28
s
# Out:
# Avocado       2.00
# Apple         2.00
# grape         3.00
# strwaberry    4.00
# Mango         2.28
# Name: protien, dtype: float64

# %%
# not operation
s=s[~(s>=3)]
s
# Out:
# Avocado    2.00
# Apple      2.00
# Mango      2.28
# Name: protien, dtype: float64

# %%
dic = {
    "name":["Divya", "Arha", "Haritha"],
    "score":[2, 6, 7],
    "color":["Red", "Blue", "Green"]

}
df = pd.DataFrame(dic)
df
# Out:
#       name  score  color
# 0    Divya      2    Red
# 1     Arha      6   Blue
# 2  Haritha      7  Green

# %%
df.head()
# Out:
#       name  score  color
# 0    Divya      2    Red
# 1     Arha      6   Blue
# 2  Haritha      7  Green

# %%
df.head(2)
# Out:
#     name  score color
# 0  Divya      2   Red
# 1   Arha      6  Blue

# %%
df.tail(2)
# Out:
#       name  score  color
# 1     Arha      6   Blue
# 2  Haritha      7  Green

# %%
# loc and iloc
df.iloc[1:3]
# Out:
#       name  score  color
# 1     Arha      6   Blue
# 2  Haritha      7  Green

# %%
df.loc[1:3, ["score", "color"]]
# Out:
#    score  color
# 1      6   Blue
# 2      7  Green

# %%
df.drop('color', axis=1) #(inplace=True affect original df )
# Out:
#       name  score
# 0    Divya      2
# 1     Arha      6
# 2  Haritha      7

# %%
df
# Out:
#       name  score  color
# 0    Divya      2    Red
# 1     Arha      6   Blue
# 2  Haritha      7  Green

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   name    3 non-null      object
#  1   score   3 non-null      int64
#  2   color   3 non-null      object
# dtypes: int64(1), object(2)
# memory usage: 204.0+ bytes

# %%
df.describe()
# Out:
#           score
# count  3.000000
# mean   5.000000
# std    2.645751
# min    2.000000
# 25%    4.000000
# 50%    6.000000
# 75%    6.500000
# max    7.000000

# %%
# Broadcasting
df["score"] = df["score"] + 6
df["score"]
# Out:
# 0    32
# 1    36
# 2    37
# Name: score, dtype: int64

# %%
# Renaming colums
df.rename(columns={"color": "COLOR"}, inplace=True)
df
# Out:
#       name  score  COLOR
# 0    Divya     32    Red
# 1     Arha     36   Blue
# 2  Haritha     37  Green

# %%
df["score"].unique()
# Out:
# array([32, 36, 37])

# %%
df["COLOR"].value_counts()
# Out:
# COLOR
# Red      1
# Blue     1
# Green    1
# Name: count, dtype: int64

# %%
df["promoted score"] = df["score"]*2
df
# Out:
#       name  score  COLOR  promoted score
# 0    Divya     32    Red              64
# 1     Arha     36   Blue              72
# 2  Haritha     37  Green              74

# %%
# Data cleaning
df.isnull().sum()
# Out:
# name              0
# score             0
# COLOR             0
# promoted score    0
# dtype: int64

# %%
dic = {
    "name":["Divya", "Arha", "Haritha", "Ram"],
    "score":[2, 6, 7, None],
    "color":["Red", "Blue", None, "Green", ]

}
df2 = pd.DataFrame(dic)
df2.head()
# Out:
#       name  score  color
# 0    Divya    2.0    Red
# 1     Arha    6.0   Blue
# 2  Haritha    7.0   None
# 3      Ram    NaN  Green

# %%
df2.dropna()
# Out:
#     name  score color
# 0  Divya    2.0   Red
# 1   Arha    6.0  Blue

# %%
df2.dropna(how="any") #by default it will be any
# Out:
#     name  score color
# 0  Divya    2.0   Red
# 1   Arha    6.0  Blue

# %%
df2.dropna(how="all") #all the values in row should be none to be dropped
# Out:
#       name  score  color
# 0    Divya    2.0    Red
# 1     Arha    6.0   Blue
# 2  Haritha    7.0   None
# 3      Ram    NaN  Green

# %%
df2.fillna(0) #value must be provided
# Out:
#       name  score  color
# 0    Divya    2.0    Red
# 1     Arha    6.0   Blue
# 2  Haritha    7.0      0
# 3      Ram    0.0  Green

# %%
df2["score"].fillna(df2["score"].mean()) #value must be provided
# Out:
# 0    2.0
# 1    6.0
# 2    7.0
# 3    5.0
# Name: score, dtype: float64

# %%
df2["color"].fillna(method="bfill")
# Out:
# /tmp/ipykernel_1790/3604501198.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["color"].fillna(method="bfill")
# 0      Red
# 1     Blue
# 2    Green
# 3    Green
# Name: color, dtype: object

# %%
df2["color"].fillna(method="ffill")
# Out:
# /tmp/ipykernel_1790/619994790.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df2["color"].fillna(method="ffill")
# 0      Red
# 1     Blue
# 2     Blue
# 3    Green
# Name: color, dtype: object

# %%
df2["name"].replace("Arha", "Joshi") # to replcae  a particulat value
# Out:
# 0      Divya
# 1      Joshi
# 2    Haritha
# 3        Ram
# Name: name, dtype: object

# %%
# Duplicates:
dic = {
    "name":["Divya", "Divya", "Haritha", "Ram"],
    "score":[2, 2, 7, None],
    "color":["Red", "Red", None, "Green", ]

}
df2 = pd.DataFrame(dic)
df2.head()
df_dup = df2[df2.duplicated]
df_dup
df_dup = df2[df2.duplicated(keep="first")]
df_dup
# Out:
#     name  score color
# 1  Divya    2.0   Red

# %%
df2.drop_duplicates()
# Out:
#       name  score  color
# 0    Divya    2.0    Red
# 2  Haritha    7.0   None
# 3      Ram    NaN  Green

# %%
df2
# Out:
#       name  score  color
# 0    Divya   2.00    Red
# 1    Divya   2.00    Red
# 2  Haritha   1.75   None
# 3      Ram    NaN  Green

# %%
#invalid values
#Lambda -> Python
df2
df2["score"]=df2["score"].apply(lambda x:x/2 if x>=2 else x)
df2
# Out:
#       name  score  color
# 0    Divya   1.00    Red
# 1    Divya   1.00    Red
# 2  Haritha   1.75   None
# 3      Ram    NaN  Green

# %%
dic = {
    "name":["Divya", "Divya", "Haritha", "Ram"],
    "score":[2, 2, 7, None],
    "color":["Red", "Red", None, "Green", ]

}
df2 = pd.DataFrame(dic)
df2["name"].replace("Divya", "Divya_Reddy", inplace=True)
df2.head()
# Out:
# /tmp/ipykernel_1790/2046882593.py:8: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df2["name"].replace("Divya", "Divya_Reddy", inplace=True)
#           name  score  color
# 0  Divya_Reddy    2.0    Red
# 1  Divya_Reddy    2.0    Red
# 2      Haritha    7.0   None
# 3          Ram    NaN  Green

# %%
df2["first_name", "last_name"] = df2["name"].str.split("_")
df2
# Out:
#           name  score  color (first_name, last_name)
# 0  Divya_Reddy    2.0    Red          [Divya, Reddy]
# 1  Divya_Reddy    2.0    Red          [Divya, Reddy]
# 2      Haritha    7.0   None               [Haritha]
# 3          Ram    NaN  Green                   [Ram]

# %%
#apply and lamda

def multpily(x):
  return x*2
df2["score"] = df2["score"].apply(multpily)
df2
# Out:
#           name  score  color (first_name, last_name)
# 0  Divya_Reddy    4.0    Red          [Divya, Reddy]
# 1  Divya_Reddy    4.0    Red          [Divya, Reddy]
# 2      Haritha   14.0   None               [Haritha]
# 3          Ram    NaN  Green                   [Ram]

# %%
df2["score"] = df2["score"].apply(lambda x: x/2)
df2
# Out:
#           name  score  color (first_name, last_name)
# 0  Divya_Reddy    2.0    Red          [Divya, Reddy]
# 1  Divya_Reddy    2.0    Red          [Divya, Reddy]
# 2      Haritha    7.0   None               [Haritha]
# 3          Ram    NaN  Green                   [Ram]

# %%
dic = {
    "name":["Divya", "Divya", "Haritha", "Ram"],
    "score1":[2, 2, 7, None],
    "color1":["Red", "Red", None, "Green", ]

}
df2 = pd.DataFrame(dic)
df2.head()
# Out:
#       name  score1 color1
# 0    Divya     2.0    Red
# 1    Divya     2.0    Red
# 2  Haritha     7.0   None
# 3      Ram     NaN  Green

# %%
# Joins
#left right outer inner merge joins
pd.concat([df2, df])
# Out:
#      name1  score1 color1     name  score  COLOR  promoted score  \
# 0    Divya     2.0    Red      NaN    NaN    NaN             NaN
# 1    Divya     2.0    Red      NaN    NaN    NaN             NaN
# 2  Haritha     7.0   None      NaN    NaN    NaN             NaN
# 3      Ram     NaN  Green      NaN    NaN    NaN             NaN
# 0      NaN     NaN    NaN    Divya   32.0    Red            64.0
# 1      NaN     NaN    NaN     Arha   36.0   Blue            72.0
# 2      NaN     NaN    NaN  Haritha   37.0  Green            74.0
#
#   (first_name, last_name)
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 0                 [Divya]
# 1                  [Arha]
# 2               [Haritha]

# %%
pd.concat([df2, df], axis=1)
# Out:
#      name1  score1 color1     name  score  COLOR  promoted score  \
# 0    Divya     2.0    Red    Divya   32.0    Red            64.0
# 1    Divya     2.0    Red     Arha   36.0   Blue            72.0
# 2  Haritha     7.0   None  Haritha   37.0  Green            74.0
# 3      Ram     NaN  Green      NaN    NaN    NaN             NaN
#
#   (first_name, last_name)
# 0                 [Divya]
# 1                  [Arha]
# 2               [Haritha]
# 3                     NaN

# %%
pd.merge(df2, df, on="name")
# Out:
#       name  score1 color1  score  COLOR  promoted score  \
# 0    Divya     2.0    Red     32    Red              64
# 1    Divya     2.0    Red     32    Red              64
# 2  Haritha     7.0   None     37  Green              74
#
#   (first_name, last_name)
# 0                 [Divya]
# 1                 [Divya]
# 2               [Haritha]

# %%
#importing file
data = pd.read_csv("data.csv`")
